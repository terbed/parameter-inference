# %%
from scipy import signal
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.genfromtxt('15312011-noise 1_comp_ON.txt')
data.shape
# Out:
# (1000000, 3)

# %%
T = 0.00002;
Fs = 1/T;
f_soma, Pxx_den_soma = signal.welch(data[:,2], Fs, window='hamming', nperseg=1024, scaling='spectrum')
f_dend, Pxx_den_dend = signal.welch(data[:,1], Fs, window='hamming', nperseg=1024, scaling='spectrum')

# %%
plt.semilogy(f_soma, np.sqrt(Pxx_den_soma))
plt.title('Soma noise PSD')
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD')
plt.show()

# %%
plt.semilogy(f_dend, np.sqrt(Pxx_den_dend))
plt.title('dendrite noise PSD')
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD')
plt.show()
