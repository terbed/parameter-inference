# %%
from scipy import signal
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.genfromtxt('/home/terbe/parameter-inference/Noise/Data/AnalyseNoise/15312003/comp_ON.txt')
data.shape
# Out:
# (1000000, 3)

# %%
T = 0.00002;
Fs = 1/T;
f_soma, Pxx_den_soma = signal.welch(data[:,2], Fs, window='hamming', nperseg=1024, scaling='spectrum')
f_dend, Pxx_den_dend = signal.welch(data[:,1], Fs, window='hamming', nperseg=1024, scaling='spectrum')

# %%
plt.figure(figsize=(12,6))
plt.semilogy(f_soma, np.sqrt(Pxx_den_soma), label='soma')
plt.semilogy(f_dend, np.sqrt(Pxx_den_dend), label='dend')
plt.title('Noise PSD | 0-25kH')
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD')
plt.legend();
plt.grid();
plt.show()

# %%
f_soma, Pxx_den_soma = signal.welch(data[:,2], Fs, window='hamming', nperseg=100000, scaling='spectrum')
f_dend, Pxx_den_dend = signal.welch(data[:,1], Fs, window='hamming', nperseg=100000, scaling='spectrum')

# %%
len(f_soma)
# Out:
# 500001

# %%
plt.figure(figsize=(12,6))
plt.semilogy(f_soma[0:25], np.sqrt(Pxx_den_soma[0:25]), label='soma')
plt.semilogy(f_dend[0:25], np.sqrt(Pxx_den_dend[0:25]), label='dend')
plt.title('Noise PSD | 0-1kHZ')
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD')
plt.legend();
plt.grid();
plt.show()

# %% [markdown]
# ##
